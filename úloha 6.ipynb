# %%
# Načtení knihoven a deklarování proměnných 
from turtle import position
import pyautogui
import time
import numpy as np
import random as r
pozice = []
seminko = 0

# %%
print('Pohybujte myší po obrazovce pro vygenerování semínka.')
for i in range(20):
    x, y = pyautogui.position()
    pozice.append((x, y))
    print(f'Pozice myši '+str(x) + ' '+str(y) + ' zaznamenána.')
    for i in pozice:
        seminko += np.math.factorial(sum(i))
    time.sleep(0.2)
print(f'Náhodně vygenerované semínko: {seminko}')
# Out:
# Pohybujte myší po obrazovce pro vygenerování semínka.
# Pozice myši 64 373 zaznamenána.
# Pozice myši 64 373 zaznamenána.
# Pozice myši 64 373 zaznamenána.
# Pozice myši 342 518 zaznamenána.
# Pozice myši 622 675 zaznamenána.
# Pozice myši 628 854 zaznamenána.
# Pozice myši 246 738 zaznamenána.
# Pozice myši 280 464 zaznamenána.
# Pozice myši 523 420 zaznamenána.
# Pozice myši 761 536 zaznamenána.
# Pozice myši 815 713 zaznamenána.
# Pozice myši 821 850 zaznamenána.
# Pozice myši 558 883 zaznamenána.
# Pozice myši 387 785 zaznamenána.
# Pozice myši 333 569 zaznamenána.
# Pozice myši 433 462 zaznamenána.
# Pozice myši 645 439 zaznamenána.
# Pozice myši 879 439 zaznamenána.
# Pozice myši 1004 391 zaznamenána.
# Pozice myši 1004 306 zaznamenána.
# Náhodně vygenerované semínko: ...
