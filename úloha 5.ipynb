# %%
# Načtení knihoven a deklarování tří funkcí
import numpy as np
import matplotlib.pyplot as plt
import timeit

fce1 = lambda x: 3*x**3 - 5*x**2 + 5*x - 8
fce2 = lambda x: x + np.exp(2*x) - 5
fce3 = lambda x: np.cos(x+9)

# %%
def bisekce(f, a0, b0, eps=1E-10):
    a, b = a0, b0
    while b - a > 2*eps:
        x = (a + b)/2
        if f(a)*f(x) < 0:
            b = x
        else:
            a = x
    return x

def newton(f, a0, b0, delta=1E-10):
    a, b = a0, b0
    def df(x, h = 1E-10):
        return (f(x+h)-f(x-h))/(2*h)
    xnew = (a+b)/2
    xold = a
    while abs(xnew - xold) > delta:
        xold = xnew
        xnew = xold - f(xold)/df(xold)
    return xnew

def graf(f, a0, b0, x, title):
    print("root: ", x)
    plt.title(title)
    plt.plot(x, f(x), "ro", label="Kořen")                                              
    plt.plot(np.linspace(a0, b0, 100), f(np.linspace(a0, b0, 100)), "b", label="f(x)")
    plt.axhline(y=0, color="black", linestyle="--")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend()
    plt.show()

# %%
# Funkce 1
a, b = 0 , 4
graf(fce1, a, b, bisekce(fce1, a, b), "Bisekce: 3*x**3 - 5*x**2 + 5*x - 8")
graf(fce1, a, b, newton(fce1, a, b), "Newton: 3*x**3 - 5*x**2 + 5*x - 8")
time1 = timeit.timeit(lambda: bisekce(fce2, a, b), number=5000)
time2 = timeit.timeit(lambda: newton(fce2, a, b), number=5000)
print(f"Bisekce: {time1/5000}s, Newton: {time2/5000}s")
# Out:
# root:  1.6411833401070908
# root:  1.641183340217298
# Bisekce: 9.147135999992315e-05s, Newton: 3.521953999988909e-05s

# %%
# Funkce 2
a, b = -2, 4
graf(fce2, a, b, bisekce(fce2, a, b), "Bisekce: x + e^(2*x) - 5")
graf(fce2, a, b, newton(fce2, a, b), "Newton: x + e^(2*x) - 5")
time1 = timeit.timeit(lambda: bisekce(fce2, a, b), number=5000)
time2 = timeit.timeit(lambda: newton(fce2, a, b), number=5000)
print(f"Bisekce: {time1/5000}s, Newton: {time2/5000}s")
# Out:
# root:  0.7262462676153518
# root:  0.7262462676458267
# Bisekce: 9.863380000006145e-05s, Newton: 2.340299999996205e-05s

# %%
# Funkce 3
a, b = -5 , 5
graf(fce3, a, b, bisekce(fce3, a, b), "Bisekce: cos(x+9)")
graf(fce3, a, b, newton(fce3, a, b), "Newton: cos(x+9)")
time1 = timeit.timeit(lambda: bisekce(fce3, a, b), number=5000)
time2 = timeit.timeit(lambda: newton(fce3, a, b), number=5000)
print(f"Bisekce: {time1/5000}s, Newton: {time2/5000}s")
# Out:
# root:  1.9955742875754368
# root:  -1.146018366025517
# Bisekce: 9.207303999992291e-05s, Newton: 2.8938379999999596e-05s
